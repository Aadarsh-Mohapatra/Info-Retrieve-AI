# %% [markdown]
# # Finetune IRS : GPT-4

# %% [markdown]
# ## Setup

# %%
# Setup directory
# %cd E:/Github_Repo/Info-Retrieve-AI/

# %%
# Install required packages
# %pip install -r raga_requirements.txt
# %pip install sentence_transformers rouge nltk bert-score

# %%
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Import necessary modules
import os
from __init__ import cfg
import pandas as pd
import requests
from bs4 import BeautifulSoup  # If web scraping is needed directly in RAGA
from huggingface_hub import HfApi  # For interacting with Hugging Face Hub if necessary
import ragas
from ragas import evaluate
from ragas.metrics import faithfulness, answer_relevancy, context_precision, context_relevancy, context_recall, context_entity_recall, answer_similarity, answer_correctness
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from pinecone import Pinecone, ServerlessSpec
import nltk
from nltk.translate.bleu_score import sentence_bleu
from rouge import Rouge
from datasets import Dataset
from bert_score import score as bert_score

# Set environment variables for API access
os.environ['HF_HOME'] = '/content/drive/MyDrive/Colab_Notebooks/Capstone_Project/Web_URL/IRS_Models/RAGA/huggingface'
os.environ['TRANSFORMERS_CACHE'] = os.environ['HF_HOME']
os.environ['HF_DATASETS_CACHE'] = os.environ['HF_HOME']
os.environ['HF_METRICS_CACHE'] = os.environ['HF_HOME']
os.environ['HF_TOKEN'] = cfg.HF_TOKEN
os.environ['OPENAI_API_KEY'] = cfg.OPENAI_API_KEY

nltk.download('punkt')
rouge = Rouge()
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab_Notebooks/Capstone_Project/Web_URL/IRS_Models/RAGA
# Collecting ragas (from -r raga_requirements.txt (line 1))
#   Downloading ragas-0.1.7-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from -r raga_requirements.txt (line 2)) (2.2.1+cu121)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from -r raga_requirements.txt (line 3)) (4.40.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r raga_requirements.txt (line 4)) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r raga_requirements.txt (line 5)) (2.0.3)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from -r raga_requirements.txt (line 6)) (0.20.3)
# Collecting pinecone-client==4.0.0 (from -r raga_requirements.txt (line 7))
#   Downloading pinecone_client-4.0.0-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.5/214.5 kB 14.3 MB/s eta 0:00:00
# Collecting bs4 (from -r raga_requirements.txt (line 8))
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.10/dist-packages (from pinecone-client==4.0.0->-r raga_requirements.txt (line 7)) (2024.2.2)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.10/dist-packages (from pinecone-client==4.0.0->-r raga_requirements.txt (line 7)) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.10/dist-packages (from pinecone-client==4.0.0->-r raga_requirements.txt (line 7)) (4.11.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from pinecone-client==4.0.0->-r raga_requirements.txt (line 7)) (2.0.7)
# Collecting datasets (from ragas->-r raga_requirements.txt (line 1))
#   Downloading datasets-2.19.1-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 39.6 MB/s eta 0:00:00
# Collecting tiktoken (from ragas->-r raga_requirements.txt (line 1))
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 48.2 MB/s eta 0:00:00
# Collecting langchain (from ragas->-r raga_requirements.txt (line 1))
#   Downloading langchain-0.2.0-py3-none-any.whl (973 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.7/973.7 kB 32.5 MB/s eta 0:00:00
# Collecting langchain-core (from ragas->-r raga_requirements.txt (line 1))
#   Downloading langchain_core-0.2.0-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.9/307.9 kB 16.4 MB/s eta 0:00:00
# Collecting langchain-community (from ragas->-r raga_requirements.txt (line 1))
#   Downloading langchain_community-0.2.0-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 51.9 MB/s eta 0:00:00
# Collecting langchain-openai (from ragas->-r raga_requirements.txt (line 1))
#   Downloading langchain_openai-0.1.7-py3-none-any.whl (34 kB)
# Collecting openai>1 (from ragas->-r raga_requirements.txt (line 1))
#   Downloading openai-1.30.1-py3-none-any.whl (320 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.6/320.6 kB 24.0 MB/s eta 0:00:00
# Collecting pysbd>=0.3.4 (from ragas->-r raga_requirements.txt (line 1))
#   Downloading pysbd-0.3.4-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from ragas->-r raga_requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/dist-packages (from ragas->-r raga_requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->-r raga_requirements.txt (line 2)) (3.14.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->-r raga_requirements.txt (line 2)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->-r raga_requirements.txt (line 2)) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->-r raga_requirements.txt (line 2)) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->-r raga_requirements.txt (line 2)) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->-r raga_requirements.txt (line 2))
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->-r raga_requirements.txt (line 2))
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->-r raga_requirements.txt (line 2))
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->-r raga_requirements.txt (line 2))
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->-r raga_requirements.txt (line 2))
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->-r raga_requirements.txt (line 2))
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->-r raga_requirements.txt (line 2))
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->-r raga_requirements.txt (line 2))
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->-r raga_requirements.txt (line 2))
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch->-r raga_requirements.txt (line 2))
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->-r raga_requirements.txt (line 2))
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->-r raga_requirements.txt (line 2)) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->-r raga_requirements.txt (line 2))
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers->-r raga_requirements.txt (line 3)) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers->-r raga_requirements.txt (line 3)) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->-r raga_requirements.txt (line 3)) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->-r raga_requirements.txt (line 3)) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers->-r raga_requirements.txt (line 3)) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->-r raga_requirements.txt (line 3)) (0.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->-r raga_requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r raga_requirements.txt (line 5)) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r raga_requirements.txt (line 5)) (2024.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->-r raga_requirements.txt (line 8)) (4.12.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai>1->ragas->-r raga_requirements.txt (line 1)) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>1->ragas->-r raga_requirements.txt (line 1)) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai>1->ragas->-r raga_requirements.txt (line 1))
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai>1->ragas->-r raga_requirements.txt (line 1)) (2.7.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai>1->ragas->-r raga_requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->-r raga_requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->-r raga_requirements.txt (line 8)) (2.5)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->ragas->-r raga_requirements.txt (line 1)) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->ragas->-r raga_requirements.txt (line 1)) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->ragas->-r raga_requirements.txt (line 1))
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.2 MB/s eta 0:00:00
# Collecting xxhash (from datasets->ragas->-r raga_requirements.txt (line 1))
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 21.8 MB/s eta 0:00:00
# Collecting multiprocess (from datasets->ragas->-r raga_requirements.txt (line 1))
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.6 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->ragas->-r raga_requirements.txt (line 1)) (3.9.5)
# Collecting huggingface-hub (from -r raga_requirements.txt (line 6))
#   Downloading huggingface_hub-0.23.0-py3-none-any.whl (401 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 34.6 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->-r raga_requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->-r raga_requirements.txt (line 3)) (3.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->-r raga_requirements.txt (line 2)) (2.1.5)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain->ragas->-r raga_requirements.txt (line 1)) (2.0.30)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain->ragas->-r raga_requirements.txt (line 1)) (4.0.3)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain->ragas->-r raga_requirements.txt (line 1))
#   Downloading dataclasses_json-0.6.6-py3-none-any.whl (28 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain->ragas->-r raga_requirements.txt (line 1))
#   Downloading langchain_text_splitters-0.2.0-py3-none-any.whl (23 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain->ragas->-r raga_requirements.txt (line 1))
#   Downloading langsmith-0.1.59-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.2/121.2 kB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain->ragas->-r raga_requirements.txt (line 1)) (8.3.0)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core->ragas->-r raga_requirements.txt (line 1))
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting packaging>=20.0 (from transformers->-r raga_requirements.txt (line 3))
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->-r raga_requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ragas->-r raga_requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ragas->-r raga_requirements.txt (line 1)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ragas->-r raga_requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ragas->-r raga_requirements.txt (line 1)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ragas->-r raga_requirements.txt (line 1)) (1.9.4)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>1->ragas->-r raga_requirements.txt (line 1)) (1.2.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain->ragas->-r raga_requirements.txt (line 1))
#   Downloading marshmallow-3.21.2-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 5.5 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain->ragas->-r raga_requirements.txt (line 1))
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai>1->ragas->-r raga_requirements.txt (line 1))
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.6 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai>1->ragas->-r raga_requirements.txt (line 1))
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.3 MB/s eta 0:00:00
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core->ragas->-r raga_requirements.txt (line 1))
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain->ragas->-r raga_requirements.txt (line 1))
#   Downloading orjson-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 17.0 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai>1->ragas->-r raga_requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai>1->ragas->-r raga_requirements.txt (line 1)) (2.18.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain->ragas->-r raga_requirements.txt (line 1)) (3.0.3)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain->ragas->-r raga_requirements.txt (line 1))
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: xxhash, pysbd, pinecone-client, packaging, orjson, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mypy-extensions, jsonpointer, h11, dill, typing-inspect, tiktoken, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, marshmallow, jsonpatch, huggingface-hub, httpcore, bs4, nvidia-cusolver-cu12, langsmith, httpx, dataclasses-json, openai, langchain-core, datasets, langchain-text-splitters, langchain-openai, langchain, langchain-community, ragas
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
# Successfully installed bs4-0.0.2 dataclasses-json-0.6.6 datasets-2.19.1 dill-0.3.8 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 huggingface-hub-0.23.0 jsonpatch-1.33 jsonpointer-2.4 langchain-0.2.0 langchain-community-0.2.0 langchain-core-0.2.0 langchain-openai-0.1.7 langchain-text-splitters-0.2.0 langsmith-0.1.59 marshmallow-3.21.2 multiprocess-0.70.16 mypy-extensions-1.0.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 openai-1.30.1 orjson-3.10.3 packaging-23.2 pinecone-client-4.0.0 pysbd-0.3.4 ragas-0.1.7 tiktoken-0.7.0 typing-inspect-0.9.0 xxhash-3.4.1
# Collecting sentence_transformers
#   Downloading sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 3.9 MB/s eta 0:00:00
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Collecting bert-score
#   Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.40.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.2.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.23.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (9.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.31.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert-score) (3.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert-score) (23.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2023.6.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (4.11.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2024.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence_transformers) (12.4.127)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (0.4.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (2024.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.3.0)
# Installing collected packages: rouge, sentence_transformers, bert-score
# Successfully installed bert-score-0.3.13 rouge-1.0.1 sentence_transformers-2.7.0
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ## Load Synthetic Baseline Responses

# %%
# Read the Dataset
data = pd.read_csv(r"E:\Github_Repo\Info-Retrieve-AI\RAGAs\output\syn_gpt_qa_50.csv")

# Fill NaN values in 'ground_truth' column with a specific placeholder
data['ground_truth'] = data['ground_truth'].fillna('No response available')
data
# Out:
#                                              question  \
# 0   What challenges do auto manufacturers face in ...
# 1   What was the limitation of the quick-serve res...
# 2   How does negative press coverage impact a bran...
# 3   How does EVForward provide valuable insight in...
# 4   What challenges do landlords face when install...
# 5   How can effective sponsorship measurement help...
# 6   What is the current availability of charging s...
# 7   How is the global rideshare industry projected...
# 8   What is the importance of delivering multiface...
# 9   What are some of the specific areas that manuf...
# 10  What are some factors that can spur the adopti...
# 11  How can projective exercises contribute to ach...
# 12  How can manufacturers train new car buyers to ...
# 13  How do qualitative methodologies vary internat...
# 14  How will the demand for video-conferencing sys...
# 15  What insights were shared about EV buyers in t...
# 16  What are some innovative techniques being used...
# 17  How can dealerships position themselves as a r...
# 18  What is the importance of ensuring appropriate...
# 19  How can automakers and utility companies incre...
# 20  How does 5G enable real-time data transmission...
# 21  What is the preference of car shoppers regardi...
# 22  Why is there a lack of measurement and researc...
# 23  What factor contributed to the market doubling...
# 24  Why is truth in advertising important for both...
# 25  How would UK and US car buyers react to overni...
# 26  How can a partner help a business find new gro...
# 27  What indicators suggest the need for a data ma...
# 28  How does EVForward assist businesses in unders...
# 29  What challenges do landlords face when install...
# 30  Why measure sponsorships and how does it aid i...
# 31  What key capabilities of BEVs need to be addre...
# 32  Why do businesses choose flexible Implementati...
# 33  What insights does EVForward offer to business...
# 34  Why is it important for industry players to re...
# 35  How can organizations ensure a comprehensive v...
# 36  How does a random probability sample in the re...
# 37  What market challenges do auto manufacturers f...
# 38  What challenges do people in multifamily housi...
# 39  How does Escalent contribute to the success of...
# 40  What insights does EVForward offer about the E...
# 41  What challenges do landlords face when providi...
# 42  Why is considering customers' emotions during ...
# 43  What are the advantages and obstacles to wides...
# 44  What effects do ridesharing services have on v...
# 45  How can automotive dealers use maintenance and...
# 46  How can the 6-D Model inform the creation of l...
# 47  What evidence-based suggestions can be impleme...
# 48  How has increased battery capacity affected ra...
# 49  What advantages does Escalent's Implementation...
#
#                                              contexts  \
# 0   ['In both the UK and US, there is currently a ...
# 1   [' quick-serve restaurant (QSR) we worked with...
# 2   [' spurred viral videos of fans destroying the...
# 3   [' to much more effective results.\n\n\nEVForw...
# 4   [' sharing (i.e., if multiple EVs are plugged ...
# 5   [' marketers don’t see the value, or worse sti...
# 6   ['EV Potential Not Yet Realized\n\n\nAs we loo...
# 7   ['It’s safe to say that ridesharing services l...
# 8   ['there’s an obstacle in my way\n—\nperhaps I ...
# 9   ['For fans of the Terminator series of movies,...
# 10  ['asm? Fleet decision-makers want evidence tha...
# 11  [' the brain, which is what properly construct...
# 12  [' to evaluate which packages or level of trim...
# 13  ['As a researcher who devoted 10 years to cond...
# 14  ['Over seven years ago I started work at Escal...
# 15  ['. The Chinese Are Coming, and What It Means ...
# 16  [', neither Trump nor Biden seem to be as impa...
# 17  ['Despite the growth of low-touch, online and ...
# 18  [' to ensure that the design and logistics are...
# 19  ['To create the conditions for more battery el...
# 20  [' increasing amounts of intermittent renewabl...
# 21  ['Reports of Tesla’s retail model dominating t...
# 22  ['The high impact but oft-forgotten area of br...
# 23  [' model – the Tesla Model 3. This car managed...
# 24  ['There was a time when brands had near-comple...
# 25  ['In both the UK and US, there is currently a ...
# 26  [' us to understand the various motivations be...
# 27  ['Dashboards consolidate and organize vast amo...
# 28  [' to much more effective results.\n\n\nEVForw...
# 29  [' sharing (i.e., if multiple EVs are plugged ...
# 30  [' marketers don’t see the value, or worse sti...
# 31  ['EV Potential Not Yet Realized\n\n\nAs we loo...
# 32  ['Whew! \nCongratulations. You’ve \nofficially...
# 33  [' to much more effective results.\n\n\nEVForw...
# 34  ['t spend unless they feel safe. Therefore, it...
# 35  ['ary Market Research: \nTapping into the vast...
# 36  [' gender to match the demographics of the new...
# 37  ['In both the UK and US, there is currently a ...
# 38  ['In our discussions with electric vehicle (EV...
# 39  [' solutions in the Validate phase. The \nVali...
# 40  [' to much more effective results.\n\n\nEVForw...
# 41  [' sharing (i.e., if multiple EVs are plugged ...
# 42  ['Last year was a big year for mergers and acq...
# 43  ['EV Potential Not Yet Realized\n\n\nAs we loo...
# 44  ['It’s safe to say that ridesharing services l...
# 45  ['With the improved quality of vehicles, techn...
# 46  ['Cross-cultural research should be a key ingr...
# 47  ['Hangouts. Houseparty. Zoom. BlueJeans. Teams...
# 48  ['Since their inception, the biggest concern f...
# 49  ['Leveraging \nEscalent’s\n \nI\nm\np\nl\nemen...
#
#                                          ground_truth evolution_type  \
# 0   Severe price increases imposed via tariffs tha...         simple
# 1   The quick-serve restaurant's segmentation solu...         simple
# 2                               No response available         simple
# 3   EVForward provides valuable insight into the E...         simple
# 4   Landlords face a balancing act in installing i...         simple
# 5   Effective sponsorship measurement provides det...         simple
# 6   The number of public charging stations has inc...         simple
# 7   The global rideshare industry is projected to ...         simple
# 8   The critical support offered to EV buyers need...         simple
# 9   Manufacturers, suppliers, and technology compa...         simple
# 10  Pilot test programs, partnering with a company...         simple
# 11  Projective exercises can contribute to achievi...         simple
# 12  Manufacturers can train new car buyers on how ...         simple
# 13  Qualitative methodologies can vary internation...         simple
# 14  Demand for high-end video-conferencing systems...         simple
# 15  K.C. Boyce shared insights on the characterist...         simple
# 16  The USC Dornsife Center for Economic and Socia...         simple
# 17  Dealerships can position themselves as a relia...         simple
# 18                              No response available         simple
# 19  Automakers and utility companies can increase ...         simple
# 20  With 5G, doctors are handed a whole new set of...         simple
# 21  57% of all respondents prefer the traditional ...         simple
# 22  The reasons for the lack of measurement and re...         simple
# 23  Its increased range – up to 300 miles on a cha...         simple
# 24  Truth in advertising is important for both con...         simple
# 25  In the UK, only 17% of car buyers would stick ...      reasoning
# 26  A partner can help a business find new growth ...      reasoning
# 27  The indicators that suggest the need for a dat...      reasoning
# 28  EVForward assists businesses in understanding ...      reasoning
# 29  Landlords face a balancing act in installing i...      reasoning
# 30  Measurement of sponsorships is important for s...      reasoning
# 31  The key capabilities of BEVs that need to be a...      reasoning
# 32  Businesses choose flexible Implementation Cons...      reasoning
# 33  EVForward offers comprehensive consumer person...      reasoning
# 34  It is important for industry players to recons...      reasoning
# 35  Organizations can ensure a comprehensive view ...      reasoning
# 36                              No response available      reasoning
# 37  Severe price increases imposed via tariffs tha...  multi_context
# 38  People in multifamily housing face challenges ...  multi_context
# 39                              No response available  multi_context
# 40  EVForward offers comprehensive consumer person...  multi_context
# 41  Landlords face a balancing act in installing i...  multi_context
# 42  Considering customers' emotions during a merge...  multi_context
# 43  The advantages of widespread EV adoption inclu...  multi_context
# 44  Ridesharing services have the potential to inc...  multi_context
# 45  Automotive dealers can use maintenance and rep...  multi_context
# 46  The 6-D Model can inform the creation of local...  multi_context
# 47  To reduce video conferencing fatigue and impro...  multi_context
# 48  While increased battery capacity has helped al...  multi_context
# 49  Escalent's Implementation Consultants offer ad...      reasoning
#
#                                              metadata  episode_done
# 0   [{'title': 'How Disruptive Pricing Will Impact...          True
# 1   [{'title': 'Obtain a Deeper, Multidimensional ...          True
# 2   [{'title': 'The Power, and Pitfalls, of Politi...          True
# 3   [{'title': 'Finding the Future of Mobility wit...          True
# 4   [{'title': 'Multifamily Housing EV Charging: W...          True
# 5   [{'title': 'Measuring the Value of Sponsorship...          True
# 6   [{'title': 'The Challenges of Making EV Easy',...          True
# 7   [{'title': 'Rideshare Vehicles: A Meaningful B...          True
# 8   [{'title': 'How to Create an “EV Easy” Mindset...          True
# 9   [{'title': 'Rise of the Smart Car: The Shape-S...          True
# 10  [{'title': 'Fleet Decision-Makers See BEVs as ...          True
# 11  [{'title': 'Superpowers and Princesses: A Thre...          True
# 12  [{'title': 'Managing Product Complexity: Incre...          True
# 13  [{'title': 'Lessons Learned Traveling the Worl...          True
# 14  [{'title': 'The Corporate Work Environment Isn...          True
# 15  [{'title': 'Three Global Industry Takeaways Fr...          True
# 16  [{'title': 'Political Polling in 2020: A Story...          True
# 17  [{'title': 'How Dealers Can Serve the Next Gen...          True
# 18  [{'title': 'Lessons Learned Traveling the Worl...          True
# 19  [{'title': 'The Importance of Increasing BEV C...          True
# 20  [{'title': '7 Industries Set to Feel the Impac...          True
# 21  [{'title': 'Despite Tesla’s Retail Model Revol...          True
# 22  [{'title': 'Measuring the Value of Sponsorship...          True
# 23  [{'title': 'Have Plug, Will Travel – The Batte...          True
# 24  [{'title': 'Truth in Advertising Has Never Bee...          True
# 25  [{'title': 'How Disruptive Pricing Will Impact...          True
# 26  [{'title': 'Phase One of Innovation: How to Fa...          True
# 27  [{'title': '7 Signs You Need a Dashboard Strat...          True
# 28  [{'title': 'Finding the Future of Mobility wit...          True
# 29  [{'title': 'Multifamily Housing EV Charging: W...          True
# 30  [{'title': 'Measuring the Value of Sponsorship...          True
# 31  [{'title': 'The Challenges of Making EV Easy',...          True
# 32  [{'title': 'Future-Proof Your Business with De...          True
# 33  [{'title': 'Finding the Future of Mobility wit...          True
# 34  [{'title': 'From C.A.S.E. to COVID-19: The Tim...          True
# 35  [{'title': 'Corporate GPS: Seeing The Forest F...          True
# 36  [{'title': 'Riding the Wave of Change: How Eur...          True
# 37  [{'title': 'How Disruptive Pricing Will Impact...          True
# 38  [{'title': 'Multifamily Housing EV Charging: W...          True
# 39  [{'title': 'Phase Two of Innovation: Engage Cr...          True
# 40  [{'title': 'Finding the Future of Mobility wit...          True
# 41  [{'title': 'Multifamily Housing EV Charging: W...          True
# 42  [{'title': 'The Value of Communication When Fa...          True
# 43  [{'title': 'The Challenges of Making EV Easy',...          True
# 44  [{'title': 'Rideshare Vehicles: A Meaningful B...          True
# 45  [{'title': 'Aging Vehicles Require Auto Dealer...          True
# 46  [{'title': 'Add Cross-Cultural Research to Use...          True
# 47  [{'title': 'From Fatigued to Fully Functional:...          True
# 48  [{'title': 'As EVs Close the Range Gap, Manufa...          True
# 49  [{'title': 'Wanted: Intelligence (Artificial o...          True

# %% [markdown]
# ## Load GPT4 responses based on synthetic baseline questions

# %%
gpt4_responses = pd.read_csv(r"E:\Github_Repo\Info-Retrieve-AI\RAGAs\output\gpt4_syn_qa_responses.csv")
gpt4_responses
# Out:
#                                              question  \
# 0   What challenges do auto manufacturers face in ...
# 1   What was the limitation of the quick-serve res...
# 2   How does negative press coverage impact a bran...
# 3   How does EVForward provide valuable insight in...
# 4   What challenges do landlords face when install...
# 5   How can effective sponsorship measurement help...
# 6   What is the current availability of charging s...
# 7   How is the global rideshare industry projected...
# 8   What is the importance of delivering multiface...
# 9   What are some of the specific areas that manuf...
# 10  What are some factors that can spur the adopti...
# 11  How can projective exercises contribute to ach...
# 12  How can manufacturers train new car buyers to ...
# 13  How do qualitative methodologies vary internat...
# 14  How will the demand for video-conferencing sys...
# 15  What insights were shared about EV buyers in t...
# 16  What are some innovative techniques being used...
# 17  How can dealerships position themselves as a r...
# 18  What is the importance of ensuring appropriate...
# 19  How can automakers and utility companies incre...
# 20  How does 5G enable real-time data transmission...
# 21  What is the preference of car shoppers regardi...
# 22  Why is there a lack of measurement and researc...
# 23  What factor contributed to the market doubling...
# 24  Why is truth in advertising important for both...
# 25  How would UK and US car buyers react to overni...
# 26  How can a partner help a business find new gro...
# 27  What indicators suggest the need for a data ma...
# 28  How does EVForward assist businesses in unders...
# 29  What challenges do landlords face when install...
# 30  Why measure sponsorships and how does it aid i...
# 31  What key capabilities of BEVs need to be addre...
# 32  Why do businesses choose flexible Implementati...
# 33  What insights does EVForward offer to business...
# 34  Why is it important for industry players to re...
# 35  How can organizations ensure a comprehensive v...
# 36  How does a random probability sample in the re...
# 37  What market challenges do auto manufacturers f...
# 38  What challenges do people in multifamily housi...
# 39  How does Escalent contribute to the success of...
# 40  What insights does EVForward offer about the E...
# 41  What challenges do landlords face when providi...
# 42  Why is considering customers' emotions during ...
# 43  What are the advantages and obstacles to wides...
# 44  What effects do ridesharing services have on v...
# 45  How can automotive dealers use maintenance and...
# 46  How can the 6-D Model inform the creation of l...
# 47  What evidence-based suggestions can be impleme...
# 48  How has increased battery capacity affected ra...
# 49  What advantages does Escalent's Implementation...
#
#                                              contexts  \
# 0   ['In both the UK and US, there is currently a ...
# 1   [' quick-serve restaurant (QSR) we worked with...
# 2   [' spurred viral videos of fans destroying the...
# 3   [' to much more effective results.\n\n\nEVForw...
# 4   [' sharing (i.e., if multiple EVs are plugged ...
# 5   [' marketers don’t see the value, or worse sti...
# 6   ['EV Potential Not Yet Realized\n\n\nAs we loo...
# 7   ['It’s safe to say that ridesharing services l...
# 8   ['there’s an obstacle in my way\n—\nperhaps I ...
# 9   ['For fans of the Terminator series of movies,...
# 10  ['asm? Fleet decision-makers want evidence tha...
# 11  [' the brain, which is what properly construct...
# 12  [' to evaluate which packages or level of trim...
# 13  ['As a researcher who devoted 10 years to cond...
# 14  ['Over seven years ago I started work at Escal...
# 15  ['. The Chinese Are Coming, and What It Means ...
# 16  [', neither Trump nor Biden seem to be as impa...
# 17  ['Despite the growth of low-touch, online and ...
# 18  [' to ensure that the design and logistics are...
# 19  ['To create the conditions for more battery el...
# 20  [' increasing amounts of intermittent renewabl...
# 21  ['Reports of Tesla’s retail model dominating t...
# 22  ['The high impact but oft-forgotten area of br...
# 23  [' model – the Tesla Model 3. This car managed...
# 24  ['There was a time when brands had near-comple...
# 25  ['In both the UK and US, there is currently a ...
# 26  [' us to understand the various motivations be...
# 27  ['Dashboards consolidate and organize vast amo...
# 28  [' to much more effective results.\n\n\nEVForw...
# 29  [' sharing (i.e., if multiple EVs are plugged ...
# 30  [' marketers don’t see the value, or worse sti...
# 31  ['EV Potential Not Yet Realized\n\n\nAs we loo...
# 32  ['Whew! \nCongratulations. You’ve \nofficially...
# 33  [' to much more effective results.\n\n\nEVForw...
# 34  ['t spend unless they feel safe. Therefore, it...
# 35  ['ary Market Research: \nTapping into the vast...
# 36  [' gender to match the demographics of the new...
# 37  ['In both the UK and US, there is currently a ...
# 38  ['In our discussions with electric vehicle (EV...
# 39  [' solutions in the Validate phase. The \nVali...
# 40  [' to much more effective results.\n\n\nEVForw...
# 41  [' sharing (i.e., if multiple EVs are plugged ...
# 42  ['Last year was a big year for mergers and acq...
# 43  ['EV Potential Not Yet Realized\n\n\nAs we loo...
# 44  ['It’s safe to say that ridesharing services l...
# 45  ['With the improved quality of vehicles, techn...
# 46  ['Cross-cultural research should be a key ingr...
# 47  ['Hangouts. Houseparty. Zoom. BlueJeans. Teams...
# 48  ['Since their inception, the biggest concern f...
# 49  ['Leveraging \nEscalent’s\n \nI\nm\np\nl\nemen...
#
#                                          ground_truth evolution_type  \
# 0   Severe price increases imposed via tariffs tha...         simple
# 1   The quick-serve restaurant's segmentation solu...         simple
# 2                               No response available         simple
# 3   EVForward provides valuable insight into the E...         simple
# 4   Landlords face a balancing act in installing i...         simple
# 5   Effective sponsorship measurement provides det...         simple
# 6   The number of public charging stations has inc...         simple
# 7   The global rideshare industry is projected to ...         simple
# 8   The critical support offered to EV buyers need...         simple
# 9   Manufacturers, suppliers, and technology compa...         simple
# 10  Pilot test programs, partnering with a company...         simple
# 11  Projective exercises can contribute to achievi...         simple
# 12  Manufacturers can train new car buyers on how ...         simple
# 13  Qualitative methodologies can vary internation...         simple
# 14  Demand for high-end video-conferencing systems...         simple
# 15  K.C. Boyce shared insights on the characterist...         simple
# 16  The USC Dornsife Center for Economic and Socia...         simple
# 17  Dealerships can position themselves as a relia...         simple
# 18                              No response available         simple
# 19  Automakers and utility companies can increase ...         simple
# 20  With 5G, doctors are handed a whole new set of...         simple
# 21  57% of all respondents prefer the traditional ...         simple
# 22  The reasons for the lack of measurement and re...         simple
# 23  Its increased range – up to 300 miles on a cha...         simple
# 24  Truth in advertising is important for both con...         simple
# 25  In the UK, only 17% of car buyers would stick ...      reasoning
# 26  A partner can help a business find new growth ...      reasoning
# 27  The indicators that suggest the need for a dat...      reasoning
# 28  EVForward assists businesses in understanding ...      reasoning
# 29  Landlords face a balancing act in installing i...      reasoning
# 30  Measurement of sponsorships is important for s...      reasoning
# 31  The key capabilities of BEVs that need to be a...      reasoning
# 32  Businesses choose flexible Implementation Cons...      reasoning
# 33  EVForward offers comprehensive consumer person...      reasoning
# 34  It is important for industry players to recons...      reasoning
# 35  Organizations can ensure a comprehensive view ...      reasoning
# 36                              No response available      reasoning
# 37  Severe price increases imposed via tariffs tha...  multi_context
# 38  People in multifamily housing face challenges ...  multi_context
# 39                              No response available  multi_context
# 40  EVForward offers comprehensive consumer person...  multi_context
# 41  Landlords face a balancing act in installing i...  multi_context
# 42  Considering customers' emotions during a merge...  multi_context
# 43  The advantages of widespread EV adoption inclu...  multi_context
# 44  Ridesharing services have the potential to inc...  multi_context
# 45  Automotive dealers can use maintenance and rep...  multi_context
# 46  The 6-D Model can inform the creation of local...  multi_context
# 47  To reduce video conferencing fatigue and impro...  multi_context
# 48  While increased battery capacity has helped al...  multi_context
# 49  Escalent's Implementation Consultants offer ad...      reasoning
#
#                                              metadata  episode_done  \
# 0   [{'title': 'How Disruptive Pricing Will Impact...          True
# 1   [{'title': 'Obtain a Deeper, Multidimensional ...          True
# 2   [{'title': 'The Power, and Pitfalls, of Politi...          True
# 3   [{'title': 'Finding the Future of Mobility wit...          True
# 4   [{'title': 'Multifamily Housing EV Charging: W...          True
# 5   [{'title': 'Measuring the Value of Sponsorship...          True
# 6   [{'title': 'The Challenges of Making EV Easy',...          True
# 7   [{'title': 'Rideshare Vehicles: A Meaningful B...          True
# 8   [{'title': 'How to Create an “EV Easy” Mindset...          True
# 9   [{'title': 'Rise of the Smart Car: The Shape-S...          True
# 10  [{'title': 'Fleet Decision-Makers See BEVs as ...          True
# 11  [{'title': 'Superpowers and Princesses: A Thre...          True
# 12  [{'title': 'Managing Product Complexity: Incre...          True
# 13  [{'title': 'Lessons Learned Traveling the Worl...          True
# 14  [{'title': 'The Corporate Work Environment Isn...          True
# 15  [{'title': 'Three Global Industry Takeaways Fr...          True
# 16  [{'title': 'Political Polling in 2020: A Story...          True
# 17  [{'title': 'How Dealers Can Serve the Next Gen...          True
# 18  [{'title': 'Lessons Learned Traveling the Worl...          True
# 19  [{'title': 'The Importance of Increasing BEV C...          True
# 20  [{'title': '7 Industries Set to Feel the Impac...          True
# 21  [{'title': 'Despite Tesla’s Retail Model Revol...          True
# 22  [{'title': 'Measuring the Value of Sponsorship...          True
# 23  [{'title': 'Have Plug, Will Travel – The Batte...          True
# 24  [{'title': 'Truth in Advertising Has Never Bee...          True
# 25  [{'title': 'How Disruptive Pricing Will Impact...          True
# 26  [{'title': 'Phase One of Innovation: How to Fa...          True
# 27  [{'title': '7 Signs You Need a Dashboard Strat...          True
# 28  [{'title': 'Finding the Future of Mobility wit...          True
# 29  [{'title': 'Multifamily Housing EV Charging: W...          True
# 30  [{'title': 'Measuring the Value of Sponsorship...          True
# 31  [{'title': 'The Challenges of Making EV Easy',...          True
# 32  [{'title': 'Future-Proof Your Business with De...          True
# 33  [{'title': 'Finding the Future of Mobility wit...          True
# 34  [{'title': 'From C.A.S.E. to COVID-19: The Tim...          True
# 35  [{'title': 'Corporate GPS: Seeing The Forest F...          True
# 36  [{'title': 'Riding the Wave of Change: How Eur...          True
# 37  [{'title': 'How Disruptive Pricing Will Impact...          True
# 38  [{'title': 'Multifamily Housing EV Charging: W...          True
# 39  [{'title': 'Phase Two of Innovation: Engage Cr...          True
# 40  [{'title': 'Finding the Future of Mobility wit...          True
# 41  [{'title': 'Multifamily Housing EV Charging: W...          True
# 42  [{'title': 'The Value of Communication When Fa...          True
# 43  [{'title': 'The Challenges of Making EV Easy',...          True
# 44  [{'title': 'Rideshare Vehicles: A Meaningful B...          True
# 45  [{'title': 'Aging Vehicles Require Auto Dealer...          True
# 46  [{'title': 'Add Cross-Cultural Research to Use...          True
# 47  [{'title': 'From Fatigued to Fully Functional:...          True
# 48  [{'title': 'As EVs Close the Range Gap, Manufa...          True
# 49  [{'title': 'Wanted: Intelligence (Artificial o...          True
#
#                                              Response
# 0   Potential massive price hikes due to trade tar...
# 1   The quick-serve restaurant's segmentation solu...
# 2   Negative press coverage can impact a brand's h...
# 3   EVForward provides valuable insight into the E...
# 4   Landlords of multifamily housing face several ...
# 5   Effective sponsorship measurement can help in ...
# 6   The text does not provide a specific number or...
# 7   The global rideshare industry is projected to ...
# 8   Delivering multifaceted EV support to EV buyer...
# 9   Manufacturers, suppliers, and technology compa...
# 10  Several factors can spur the adoption of Batte...
# 11  Projective exercises contribute to achieving g...
# 12  The context does not provide specific strategi...
# 13  Qualitative methodologies can greatly vary int...
# 14  The shift to remote work is likely to increase...
# 15  The EVForward Europe study identified six uniq...
# 16  There are several new techniques being employe...
# 17  Dealerships can position themselves as a relia...
# 18  The text does not provide information on the i...
# 19  The studies suggest several ways for automaker...
# 20  5G technology enables real-time data transmiss...
# 21  According to the DeepDive report, 57% of the r...
# 22  The article mentions several reasons why there...
# 23  The provided context does not include informat...
# 24  Truth in advertising is important for both con...
# 25  In both the UK and US, car buyers' behavior wo...
# 26  A partner, such as Escalent in the provided co...
# 27  The indicators suggesting the need for a dashb...
# 28  The text does not provide specific information...
# 29  The challenges landlords face when installing ...
# 30  Measuring sponsorships is essential to gauge t...
# 31  For widespread adoption of Battery Electric Ve...
# 32  Businesses choose flexible Implementation Cons...
# 33  EVForward offers significant insights to busin...
# 34  The COVID-19 pandemic has caused a major shift...
# 35  Organizations can ensure a comprehensive view ...
# 36  The random probability sample ensures a fair r...
# 37  Auto manufacturers face significant market cha...
# 38  People living in multifamily housing such as a...
# 39  During the Validate phase of innovation, Escal...
# 40  EVForward provides insights into the attitudes...
# 41  Landlords of multifamily housing face certain ...
# 42  Considering customers' emotions during a merge...
# 43  Advantages of EV adoption include their contri...
# 44  Ridesharing services like Uber and Lyft have m...
# 45  Automotive dealers can use maintenance and rep...
# 46  The 6-D Model can inform the creation of local...
# 47  The text suggests several methods to reduce vi...
# 48  Increased battery capacity in electric vehicle...
# 49  Using Escalent's Implementation Consultants of...

# %% [markdown]
# ## RAGA Evaluator

# %%
class LLMPerformanceEvaluator:
    def __init__(self, gpt4_responses):
        self.data = gpt4_responses
        self.rouge = Rouge()

    def preprocess_data(self):
        # Ensure ground truth data is present for all records to avoid processing errors
        filtered_data = self.data[self.data['ground_truth'] != 'No response available']

        # Tokenize text for metric calculation
        filtered_data['Reference_Tokens'] = filtered_data['ground_truth'].apply(lambda x: word_tokenize(x.lower()))
        filtered_data['Response_Tokens'] = filtered_data['Response'].apply(lambda x: word_tokenize(x.lower()))

        # Calculate BLEU and ROUGE scores only for entries with valid ground truth
        filtered_data['BLEU'] = filtered_data.apply(lambda row: sentence_bleu([row['Reference_Tokens']], row['Response_Tokens'], weights=(0.25, 0.25, 0.25, 0.25)), axis=1)
        filtered_data['ROGUE'] = filtered_data.apply(lambda row: rouge.get_scores(row['Response'], row['ground_truth'])[0]['rouge-l']['f'], axis=1)

        # Calculate BERT scores
        references = filtered_data['ground_truth'].tolist()
        predictions = filtered_data['Response'].tolist()
        P, R, F1 = bert_score(predictions, references, lang="en", verbose=True)
        filtered_data['BERT_P'] = P.numpy()
        filtered_data['BERT_R'] = R.numpy()
        filtered_data['BERT_F1'] = F1.numpy()

        # Prepare data for RAGA metrics
        self.dataset = Dataset.from_dict({
            'question': filtered_data['question'].tolist(),
            'answer': filtered_data['Response'].tolist(),
            'contexts': [nltk.sent_tokenize(x) for x in filtered_data['ground_truth']],
            'ground_truth': filtered_data['ground_truth'].tolist()
        })

        self.filtered_data = filtered_data
        return self.filtered_data

        # dataset = Dataset.from_dict(data_samples)

    def compute_raga_metrics(self, metrics):
        # Compute RAGA metrics in batches
        raga_results = evaluate(self.dataset, metrics=metrics)
        raga_df = raga_results.to_pandas()
        return raga_df

    def compute_metrics(self):
        self.preprocess_data()
        # Define batches of metrics
        metric_batches = [
            [faithfulness, answer_relevancy, context_precision],
            [context_relevancy, context_recall, context_entity_recall],
            [answer_similarity, answer_correctness]
        ]
        df = [self.filtered_data]

        for metrics in metric_batches:
            metrics_result = self.compute_raga_metrics(metrics)
            df.append(metrics_result)
        combine_df = pd.concat(df, axis=1)
        return combine_df

# %% [markdown]
# ## Evaluate Performance Metrics for GPT-4

# %%
evaluator = LLMPerformanceEvaluator(gpt4_responses)

# %%
evaluator.preprocess_data()
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 364.69 seconds, 0.13 sentences/sec
#                                              question  \
# 0   What challenges do auto manufacturers face in ...
# 1   What was the limitation of the quick-serve res...
# 3   How does EVForward provide valuable insight in...
# 4   What challenges do landlords face when install...
# 5   How can effective sponsorship measurement help...
# 6   What is the current availability of charging s...
# 7   How is the global rideshare industry projected...
# 8   What is the importance of delivering multiface...
# 9   What are some of the specific areas that manuf...
# 10  What are some factors that can spur the adopti...
# 11  How can projective exercises contribute to ach...
# 12  How can manufacturers train new car buyers to ...
# 13  How do qualitative methodologies vary internat...
# 14  How will the demand for video-conferencing sys...
# 15  What insights were shared about EV buyers in t...
# 16  What are some innovative techniques being used...
# 17  How can dealerships position themselves as a r...
# 19  How can automakers and utility companies incre...
# 20  How does 5G enable real-time data transmission...
# 21  What is the preference of car shoppers regardi...
# 22  Why is there a lack of measurement and researc...
# 23  What factor contributed to the market doubling...
# 24  Why is truth in advertising important for both...
# 25  How would UK and US car buyers react to overni...
# 26  How can a partner help a business find new gro...
# 27  What indicators suggest the need for a data ma...
# 28  How does EVForward assist businesses in unders...
# 29  What challenges do landlords face when install...
# 30  Why measure sponsorships and how does it aid i...
# 31  What key capabilities of BEVs need to be addre...
# 32  Why do businesses choose flexible Implementati...
# 33  What insights does EVForward offer to business...
# 34  Why is it important for industry players to re...
# 35  How can organizations ensure a comprehensive v...
# 37  What market challenges do auto manufacturers f...
# 38  What challenges do people in multifamily housi...
# 40  What insights does EVForward offer about the E...
# 41  What challenges do landlords face when providi...
# 42  Why is considering customers' emotions during ...
# 43  What are the advantages and obstacles to wides...
# 44  What effects do ridesharing services have on v...
# 45  How can automotive dealers use maintenance and...
# 46  How can the 6-D Model inform the creation of l...
# 47  What evidence-based suggestions can be impleme...
# 48  How has increased battery capacity affected ra...
# 49  What advantages does Escalent's Implementation...
#
#                                              contexts  \
# 0   ['In both the UK and US, there is currently a ...
# 1   [' quick-serve restaurant (QSR) we worked with...
# 3   [' to much more effective results.\n\n\nEVForw...
# 4   [' sharing (i.e., if multiple EVs are plugged ...
# 5   [' marketers don’t see the value, or worse sti...
# 6   ['EV Potential Not Yet Realized\n\n\nAs we loo...
# 7   ['It’s safe to say that ridesharing services l...
# 8   ['there’s an obstacle in my way\n—\nperhaps I ...
# 9   ['For fans of the Terminator series of movies,...
# 10  ['asm? Fleet decision-makers want evidence tha...
# 11  [' the brain, which is what properly construct...
# 12  [' to evaluate which packages or level of trim...
# 13  ['As a researcher who devoted 10 years to cond...
# 14  ['Over seven years ago I started work at Escal...
# 15  ['. The Chinese Are Coming, and What It Means ...
# 16  [', neither Trump nor Biden seem to be as impa...
# 17  ['Despite the growth of low-touch, online and ...
# 19  ['To create the conditions for more battery el...
# 20  [' increasing amounts of intermittent renewabl...
# 21  ['Reports of Tesla’s retail model dominating t...
# 22  ['The high impact but oft-forgotten area of br...
# 23  [' model – the Tesla Model 3. This car managed...
# 24  ['There was a time when brands had near-comple...
# 25  ['In both the UK and US, there is currently a ...
# 26  [' us to understand the various motivations be...
# 27  ['Dashboards consolidate and organize vast amo...
# 28  [' to much more effective results.\n\n\nEVForw...
# 29  [' sharing (i.e., if multiple EVs are plugged ...
# 30  [' marketers don’t see the value, or worse sti...
# 31  ['EV Potential Not Yet Realized\n\n\nAs we loo...
# 32  ['Whew! \nCongratulations. You’ve \nofficially...
# 33  [' to much more effective results.\n\n\nEVForw...
# 34  ['t spend unless they feel safe. Therefore, it...
# 35  ['ary Market Research: \nTapping into the vast...
# 37  ['In both the UK and US, there is currently a ...
# 38  ['In our discussions with electric vehicle (EV...
# 40  [' to much more effective results.\n\n\nEVForw...
# 41  [' sharing (i.e., if multiple EVs are plugged ...
# 42  ['Last year was a big year for mergers and acq...
# 43  ['EV Potential Not Yet Realized\n\n\nAs we loo...
# 44  ['It’s safe to say that ridesharing services l...
# 45  ['With the improved quality of vehicles, techn...
# 46  ['Cross-cultural research should be a key ingr...
# 47  ['Hangouts. Houseparty. Zoom. BlueJeans. Teams...
# 48  ['Since their inception, the biggest concern f...
# 49  ['Leveraging \nEscalent’s\n \nI\nm\np\nl\nemen...
#
#                                          ground_truth evolution_type  \
# 0   Severe price increases imposed via tariffs tha...         simple
# 1   The quick-serve restaurant's segmentation solu...         simple
# 3   EVForward provides valuable insight into the E...         simple
# 4   Landlords face a balancing act in installing i...         simple
# 5   Effective sponsorship measurement provides det...         simple
# 6   The number of public charging stations has inc...         simple
# 7   The global rideshare industry is projected to ...         simple
# 8   The critical support offered to EV buyers need...         simple
# 9   Manufacturers, suppliers, and technology compa...         simple
# 10  Pilot test programs, partnering with a company...         simple
# 11  Projective exercises can contribute to achievi...         simple
# 12  Manufacturers can train new car buyers on how ...         simple
# 13  Qualitative methodologies can vary internation...         simple
# 14  Demand for high-end video-conferencing systems...         simple
# 15  K.C. Boyce shared insights on the characterist...         simple
# 16  The USC Dornsife Center for Economic and Socia...         simple
# 17  Dealerships can position themselves as a relia...         simple
# 19  Automakers and utility companies can increase ...         simple
# 20  With 5G, doctors are handed a whole new set of...         simple
# 21  57% of all respondents prefer the traditional ...         simple
# 22  The reasons for the lack of measurement and re...         simple
# 23  Its increased range – up to 300 miles on a cha...         simple
# 24  Truth in advertising is important for both con...         simple
# 25  In the UK, only 17% of car buyers would stick ...      reasoning
# 26  A partner can help a business find new growth ...      reasoning
# 27  The indicators that suggest the need for a dat...      reasoning
# 28  EVForward assists businesses in understanding ...      reasoning
# 29  Landlords face a balancing act in installing i...      reasoning
# 30  Measurement of sponsorships is important for s...      reasoning
# 31  The key capabilities of BEVs that need to be a...      reasoning
# 32  Businesses choose flexible Implementation Cons...      reasoning
# 33  EVForward offers comprehensive consumer person...      reasoning
# 34  It is important for industry players to recons...      reasoning
# 35  Organizations can ensure a comprehensive view ...      reasoning
# 37  Severe price increases imposed via tariffs tha...  multi_context
# 38  People in multifamily housing face challenges ...  multi_context
# 40  EVForward offers comprehensive consumer person...  multi_context
# 41  Landlords face a balancing act in installing i...  multi_context
# 42  Considering customers' emotions during a merge...  multi_context
# 43  The advantages of widespread EV adoption inclu...  multi_context
# 44  Ridesharing services have the potential to inc...  multi_context
# 45  Automotive dealers can use maintenance and rep...  multi_context
# 46  The 6-D Model can inform the creation of local...  multi_context
# 47  To reduce video conferencing fatigue and impro...  multi_context
# 48  While increased battery capacity has helped al...  multi_context
# 49  Escalent's Implementation Consultants offer ad...      reasoning
#
#                                              metadata  episode_done  \
# 0   [{'title': 'How Disruptive Pricing Will Impact...          True
# 1   [{'title': 'Obtain a Deeper, Multidimensional ...          True
# 3   [{'title': 'Finding the Future of Mobility wit...          True
# 4   [{'title': 'Multifamily Housing EV Charging: W...          True
# 5   [{'title': 'Measuring the Value of Sponsorship...          True
# 6   [{'title': 'The Challenges of Making EV Easy',...          True
# 7   [{'title': 'Rideshare Vehicles: A Meaningful B...          True
# 8   [{'title': 'How to Create an “EV Easy” Mindset...          True
# 9   [{'title': 'Rise of the Smart Car: The Shape-S...          True
# 10  [{'title': 'Fleet Decision-Makers See BEVs as ...          True
# 11  [{'title': 'Superpowers and Princesses: A Thre...          True
# 12  [{'title': 'Managing Product Complexity: Incre...          True
# 13  [{'title': 'Lessons Learned Traveling the Worl...          True
# 14  [{'title': 'The Corporate Work Environment Isn...          True
# 15  [{'title': 'Three Global Industry Takeaways Fr...          True
# 16  [{'title': 'Political Polling in 2020: A Story...          True
# 17  [{'title': 'How Dealers Can Serve the Next Gen...          True
# 19  [{'title': 'The Importance of Increasing BEV C...          True
# 20  [{'title': '7 Industries Set to Feel the Impac...          True
# 21  [{'title': 'Despite Tesla’s Retail Model Revol...          True
# 22  [{'title': 'Measuring the Value of Sponsorship...          True
# 23  [{'title': 'Have Plug, Will Travel – The Batte...          True
# 24  [{'title': 'Truth in Advertising Has Never Bee...          True
# 25  [{'title': 'How Disruptive Pricing Will Impact...          True
# 26  [{'title': 'Phase One of Innovation: How to Fa...          True
# 27  [{'title': '7 Signs You Need a Dashboard Strat...          True
# 28  [{'title': 'Finding the Future of Mobility wit...          True
# 29  [{'title': 'Multifamily Housing EV Charging: W...          True
# 30  [{'title': 'Measuring the Value of Sponsorship...          True
# 31  [{'title': 'The Challenges of Making EV Easy',...          True
# 32  [{'title': 'Future-Proof Your Business with De...          True
# 33  [{'title': 'Finding the Future of Mobility wit...          True
# 34  [{'title': 'From C.A.S.E. to COVID-19: The Tim...          True
# 35  [{'title': 'Corporate GPS: Seeing The Forest F...          True
# 37  [{'title': 'How Disruptive Pricing Will Impact...          True
# 38  [{'title': 'Multifamily Housing EV Charging: W...          True
# 40  [{'title': 'Finding the Future of Mobility wit...          True
# 41  [{'title': 'Multifamily Housing EV Charging: W...          True
# 42  [{'title': 'The Value of Communication When Fa...          True
# 43  [{'title': 'The Challenges of Making EV Easy',...          True
# 44  [{'title': 'Rideshare Vehicles: A Meaningful B...          True
# 45  [{'title': 'Aging Vehicles Require Auto Dealer...          True
# 46  [{'title': 'Add Cross-Cultural Research to Use...          True
# 47  [{'title': 'From Fatigued to Fully Functional:...          True
# 48  [{'title': 'As EVs Close the Range Gap, Manufa...          True
# 49  [{'title': 'Wanted: Intelligence (Artificial o...          True
#
#                                              Response  \
# 0   Potential massive price hikes due to trade tar...
# 1   The quick-serve restaurant's segmentation solu...
# 3   EVForward provides valuable insight into the E...
# 4   Landlords of multifamily housing face several ...
# 5   Effective sponsorship measurement can help in ...
# 6   The text does not provide a specific number or...
# 7   The global rideshare industry is projected to ...
# 8   Delivering multifaceted EV support to EV buyer...
# 9   Manufacturers, suppliers, and technology compa...
# 10  Several factors can spur the adoption of Batte...
# 11  Projective exercises contribute to achieving g...
# 12  The context does not provide specific strategi...
# 13  Qualitative methodologies can greatly vary int...
# 14  The shift to remote work is likely to increase...
# 15  The EVForward Europe study identified six uniq...
# 16  There are several new techniques being employe...
# 17  Dealerships can position themselves as a relia...
# 19  The studies suggest several ways for automaker...
# 20  5G technology enables real-time data transmiss...
# 21  According to the DeepDive report, 57% of the r...
# 22  The article mentions several reasons why there...
# 23  The provided context does not include informat...
# 24  Truth in advertising is important for both con...
# 25  In both the UK and US, car buyers' behavior wo...
# 26  A partner, such as Escalent in the provided co...
# 27  The indicators suggesting the need for a dashb...
# 28  The text does not provide specific information...
# 29  The challenges landlords face when installing ...
# 30  Measuring sponsorships is essential to gauge t...
# 31  For widespread adoption of Battery Electric Ve...
# 32  Businesses choose flexible Implementation Cons...
# 33  EVForward offers significant insights to busin...
# 34  The COVID-19 pandemic has caused a major shift...
# 35  Organizations can ensure a comprehensive view ...
# 37  Auto manufacturers face significant market cha...
# 38  People living in multifamily housing such as a...
# 40  EVForward provides insights into the attitudes...
# 41  Landlords of multifamily housing face certain ...
# 42  Considering customers' emotions during a merge...
# 43  Advantages of EV adoption include their contri...
# 44  Ridesharing services like Uber and Lyft have m...
# 45  Automotive dealers can use maintenance and rep...
# 46  The 6-D Model can inform the creation of local...
# 47  The text suggests several methods to reduce vi...
# 48  Increased battery capacity in electric vehicle...
# 49  Using Escalent's Implementation Consultants of...
#
#                                      Reference_Tokens  \
# 0   [severe, price, increases, imposed, via, tarif...
# 1   [the, quick-serve, restaurant, 's, segmentatio...
# 3   [evforward, provides, valuable, insight, into,...
# 4   [landlords, face, a, balancing, act, in, insta...
# 5   [effective, sponsorship, measurement, provides...
# 6   [the, number, of, public, charging, stations, ...
# 7   [the, global, rideshare, industry, is, project...
# 8   [the, critical, support, offered, to, ev, buye...
# 9   [manufacturers, ,, suppliers, ,, and, technolo...
# 10  [pilot, test, programs, ,, partnering, with, a...
# 11  [projective, exercises, can, contribute, to, a...
# 12  [manufacturers, can, train, new, car, buyers, ...
# 13  [qualitative, methodologies, can, vary, intern...
# 14  [demand, for, high-end, video-conferencing, sy...
# 15  [k.c, ., boyce, shared, insights, on, the, cha...
# 16  [the, usc, dornsife, center, for, economic, an...
# 17  [dealerships, can, position, themselves, as, a...
# 19  [automakers, and, utility, companies, can, inc...
# 20  [with, 5g, ,, doctors, are, handed, a, whole, ...
# 21  [57, %, of, all, respondents, prefer, the, tra...
# 22  [the, reasons, for, the, lack, of, measurement...
# 23  [its, increased, range, –, up, to, 300, miles,...
# 24  [truth, in, advertising, is, important, for, b...
# 25  [in, the, uk, ,, only, 17, %, of, car, buyers,...
# 26  [a, partner, can, help, a, business, find, new...
# 27  [the, indicators, that, suggest, the, need, fo...
# 28  [evforward, assists, businesses, in, understan...
# 29  [landlords, face, a, balancing, act, in, insta...
# 30  [measurement, of, sponsorships, is, important,...
# 31  [the, key, capabilities, of, bevs, that, need,...
# 32  [businesses, choose, flexible, implementation,...
# 33  [evforward, offers, comprehensive, consumer, p...
# 34  [it, is, important, for, industry, players, to...
# 35  [organizations, can, ensure, a, comprehensive,...
# 37  [severe, price, increases, imposed, via, tarif...
# 38  [people, in, multifamily, housing, face, chall...
# 40  [evforward, offers, comprehensive, consumer, p...
# 41  [landlords, face, a, balancing, act, in, insta...
# 42  [considering, customers, ', emotions, during, ...
# 43  [the, advantages, of, widespread, ev, adoption...
# 44  [ridesharing, services, have, the, potential, ...
# 45  [automotive, dealers, can, use, maintenance, a...
# 46  [the, 6-d, model, can, inform, the, creation, ...
# 47  [to, reduce, video, conferencing, fatigue, and...
# 48  [while, increased, battery, capacity, has, hel...
# 49  [escalent, 's, implementation, consultants, of...
#
#                                       Response_Tokens           BLEU  \
# 0   [potential, massive, price, hikes, due, to, tr...   9.499367e-02
# 1   [the, quick-serve, restaurant, 's, segmentatio...   2.985456e-01
# 3   [evforward, provides, valuable, insight, into,...   1.173411e-01
# 4   [landlords, of, multifamily, housing, face, se...   1.488835e-01
# 5   [effective, sponsorship, measurement, can, hel...   1.492871e-01
# 6   [the, text, does, not, provide, a, specific, n...  3.010855e-155
# 7   [the, global, rideshare, industry, is, project...   1.000000e+00
# 8   [delivering, multifaceted, ev, support, to, ev...   9.244919e-02
# 9   [manufacturers, ,, suppliers, ,, and, technolo...   2.863862e-02
# 10  [several, factors, can, spur, the, adoption, o...   4.565686e-02
# 11  [projective, exercises, contribute, to, achiev...   1.986507e-01
# 12  [the, context, does, not, provide, specific, s...   2.438627e-01
# 13  [qualitative, methodologies, can, greatly, var...   4.991798e-02
# 14  [the, shift, to, remote, work, is, likely, to,...   5.515452e-02
# 15  [the, evforward, europe, study, identified, si...   1.270807e-02
# 16  [there, are, several, new, techniques, being, ...   2.244458e-01
# 17  [dealerships, can, position, themselves, as, a...   1.518658e-01
# 19  [the, studies, suggest, several, ways, for, au...   3.464976e-02
# 20  [5g, technology, enables, real-time, data, tra...   3.320130e-02
# 21  [according, to, the, deepdive, report, ,, 57, ...   2.717222e-01
# 22  [the, article, mentions, several, reasons, why...   2.021429e-01
# 23  [the, provided, context, does, not, include, i...  1.120041e-231
# 24  [truth, in, advertising, is, important, for, b...   1.928050e-01
# 25  [in, both, the, uk, and, us, ,, car, buyers, '...   3.064778e-01
# 26  [a, partner, ,, such, as, escalent, in, the, p...   1.319753e-01
# 27  [the, indicators, suggesting, the, need, for, ...   2.294257e-01
# 28  [the, text, does, not, provide, specific, info...   1.581387e-01
# 29  [the, challenges, landlords, face, when, insta...   7.426038e-02
# 30  [measuring, sponsorships, is, essential, to, g...   9.778386e-02
# 31  [for, widespread, adoption, of, battery, elect...   2.319976e-02
# 32  [businesses, choose, flexible, implementation,...   9.378700e-02
# 33  [evforward, offers, significant, insights, to,...   3.270046e-02
# 34  [the, covid-19, pandemic, has, caused, a, majo...   2.247913e-02
# 35  [organizations, can, ensure, a, comprehensive,...   9.257578e-02
# 37  [auto, manufacturers, face, significant, marke...   2.809114e-02
# 38  [people, living, in, multifamily, housing, suc...   2.280060e-01
# 40  [evforward, provides, insights, into, the, att...   5.446736e-02
# 41  [landlords, of, multifamily, housing, face, ce...   1.821646e-02
# 42  [considering, customers, ', emotions, during, ...   1.658749e-01
# 43  [advantages, of, ev, adoption, include, their,...   2.485581e-02
# 44  [ridesharing, services, like, uber, and, lyft,...   9.613793e-02
# 45  [automotive, dealers, can, use, maintenance, a...   9.294873e-02
# 46  [the, 6-d, model, can, inform, the, creation, ...   1.411267e-01
# 47  [the, text, suggests, several, methods, to, re...   5.718403e-02
# 48  [increased, battery, capacity, in, electric, v...   1.361232e-01
# 49  [using, escalent, 's, implementation, consulta...   2.393620e-02
#
#        ROGUE    BERT_P    BERT_R   BERT_F1
# 0   0.321678  0.874894  0.910280  0.892236
# 1   0.571429  0.921405  0.971298  0.945694
# 3   0.364780  0.862064  0.924760  0.892312
# 4   0.336957  0.870464  0.911350  0.890438
# 5   0.431373  0.907173  0.941681  0.924105
# 6   0.202247  0.867870  0.879603  0.873697
# 7   1.000000  1.000000  1.000000  1.000000
# 8   0.311927  0.866447  0.912400  0.888830
# 9   0.094862  0.806888  0.908188  0.854546
# 10  0.158996  0.814406  0.872989  0.842681
# 11  0.515152  0.897138  0.964522  0.929611
# 12  0.363636  0.922250  0.926973  0.924605
# 13  0.289655  0.838982  0.903471  0.870033
# 14  0.129032  0.876206  0.932530  0.903491
# 15  0.080717  0.803325  0.883325  0.841428
# 16  0.506667  0.889663  0.943069  0.915588
# 17  0.375000  0.874113  0.922819  0.897806
# 19  0.204255  0.843563  0.876244  0.859593
# 20  0.177778  0.829152  0.851569  0.840211
# 21  0.510638  0.921501  0.952001  0.936503
# 22  0.432749  0.907215  0.895685  0.901413
# 23  0.117647  0.833894  0.813099  0.823365
# 24  0.417391  0.875230  0.918171  0.896187
# 25  0.538462  0.909891  0.943991  0.926627
# 26  0.393162  0.873159  0.904052  0.888337
# 27  0.371429  0.923319  0.917041  0.920170
# 28  0.483871  0.918505  0.891474  0.904788
# 29  0.294931  0.844454  0.912191  0.877016
# 30  0.320346  0.860862  0.904972  0.882366
# 31  0.154762  0.835787  0.907492  0.870165
# 32  0.331288  0.867379  0.911462  0.888874
# 33  0.196319  0.824953  0.904809  0.863038
# 34  0.200000  0.840407  0.878352  0.858960
# 35  0.250000  0.839249  0.909324  0.872882
# 37  0.265896  0.845903  0.901527  0.872830
# 38  0.475472  0.895919  0.907943  0.901891
# 40  0.224852  0.846403  0.870323  0.858197
# 41  0.222222  0.838403  0.881721  0.859517
# 42  0.377622  0.883306  0.931246  0.906643
# 43  0.175439  0.833654  0.905115  0.867916
# 44  0.319444  0.876027  0.905934  0.890730
# 45  0.285714  0.880607  0.912719  0.896375
# 46  0.372093  0.865403  0.937912  0.900200
# 47  0.201058  0.842003  0.896863  0.868568
# 48  0.371795  0.904173  0.906575  0.905372
# 49  0.172043  0.820938  0.858176  0.839144

# %%
metrics_df = evaluator.compute_metrics()
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# calculating scores...
# computing bert embedding.
#   0%|          | 0/2 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 351.84 seconds, 0.13 sentences/sec
# Evaluating:   0%|          | 0/138 [00:00<?, ?it/s]
# WARNING:ragas.metrics._faithfulness:No statements were generated from the answer.
# WARNING:ragas.metrics._faithfulness:No statements were generated from the answer.
# WARNING:ragas.metrics._faithfulness:No statements were generated from the answer.
# Evaluating:   0%|          | 0/138 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/92 [00:00<?, ?it/s]

# %%
pd.set_option('display.max_columns', None)
metrics_df
# Out:
# Empty DataFrame
# Columns: [Response_Tokens, BERT_R, answer, Reference_Tokens, answer_correctness, answer_similarity, evolution_type, faithfulness, metadata, BERT_F1, BLEU, context_recall, context_entity_recall, contexts, ground_truth, question, Response, ROGUE, answer_relevancy, context_relevancy, BERT_P, context_precision, episode_done]
# Index: []

# %%
column_list = metrics_df.columns
print(column_list)
# Out:
# Index(['Response_Tokens', 'BERT_R', 'answer', 'Reference_Tokens',
#        'answer_correctness', 'answer_similarity', 'evolution_type',
#        'faithfulness', 'metadata', 'BERT_F1', 'BLEU', 'context_recall',
#        'context_entity_recall', 'contexts', 'ground_truth', 'question',
#        'Response', 'ROGUE', 'answer_relevancy', 'context_relevancy', 'BERT_P',
#        'context_precision', 'episode_done'],
#       dtype='object')

# %%
metrics_df
# Out:
# Empty DataFrame
# Columns: [Response_Tokens, BERT_R, answer, Reference_Tokens, answer_correctness, answer_similarity, evolution_type, faithfulness, metadata, BERT_F1, BLEU, context_recall, context_entity_recall, contexts, ground_truth, question, Response, ROGUE, answer_relevancy, context_relevancy, BERT_P, context_precision, episode_done]
# Index: []

# %%
column_list = set(column_list)
column_list
# Out:
# {'BERT_F1',
#  'BERT_P',
#  'BERT_R',
#  'BLEU',
#  'ROGUE',
#  'Reference_Tokens',
#  'Response',
#  'Response_Tokens',
#  'answer',
#  'answer_correctness',
#  'answer_relevancy',
#  'answer_similarity',
#  'context_entity_recall',
#  'context_precision',
#  'context_recall',
#  'context_relevancy',
#  'contexts',
#  'episode_done',
#  'evolution_type',
#  'faithfulness',
#  'ground_truth',
#  'metadata',
#  'question'}

# %%
final_df = pd.DataFrame(metrics_df,columns=list(column_list))

# %%
final_df.columns
# Out:
# Index(['Response_Tokens', 'BERT_R', 'answer', 'Reference_Tokens',
#        'answer_correctness', 'answer_similarity', 'evolution_type',
#        'faithfulness', 'metadata', 'BERT_F1', 'BLEU', 'context_recall',
#        'context_entity_recall', 'contexts', 'ground_truth', 'question',
#        'Response', 'ROGUE', 'answer_relevancy', 'context_relevancy', 'BERT_P',
#        'context_precision', 'episode_done'],
#       dtype='object')

# %%
metrics_df
# Out:
# Empty DataFrame
# Columns: [Response_Tokens, BERT_R, answer, answer, answer, Reference_Tokens, answer_correctness, answer_similarity, evolution_type, faithfulness, metadata, BERT_F1, BLEU, context_recall, context_entity_recall, contexts, contexts, contexts, contexts, ground_truth, ground_truth, ground_truth, ground_truth, question, question, question, question, Response, ROGUE, answer_relevancy, context_relevancy, BERT_P, context_precision, episode_done]
# Index: []

# %%
pd.set_option('display.max_columns', None)
metrics_df.to_csv(r"E:\Github_Repo\Info-Retrieve-AI\RAGAs\output\gpt4_performance_metrics.csv", index=False)
print("Performance metrics have been saved successfully.")

# %%
metrics_df.head()

# %% [markdown]
# ## Test

# %%
class LLMPerformanceEvaluator:

    def __init__(self, data):
        # self.model = model
        # self.indexer = indexer
        self.data = gpt4_responses

    def compute_metrics(self):
        # Ensure ground truth data is present for all records to avoid processing errors
        filtered_data = self.data.dropna(subset=['ground_truth'])

        # Preprocessing text for metric calculation
        filtered_data['Reference_Tokens'] = filtered_data['ground_truth'].apply(lambda x: nltk.word_tokenize(x.lower()))
        filtered_data['Response_Tokens'] = filtered_data['Response'].apply(lambda x: nltk.word_tokenize(x.lower()))

        # Calculate BLEU and ROUGE scores only for entries with valid ground truth
        filtered_data['BLEU'] = filtered_data.apply(lambda row: sentence_bleu([row['Reference_Tokens']], row['Response_Tokens'], weights=(0.25, 0.25, 0.25, 0.25)), axis=1)
        filtered_data['ROGUE'] = filtered_data.apply(lambda row: rouge.get_scores(row['Response'], row['ground_truth'])[0]['rouge-l']['f'], axis=1)


        # Calculate BERT scores
        # Convert to list for BERT score calculation
        references = filtered_data['ground_truth'].tolist()
        predictions = filtered_data['Response'].tolist()

        # Calculate BERT scores
        P, R, F1 = bert_score(predictions, references, lang="en", verbose=True)

        # Add BERT scores to DataFrame
        filtered_data['BERT_P'] = P.numpy()
        filtered_data['BERT_R'] = R.numpy()
        filtered_data['BERT_F1'] = F1.numpy()

        # Prepare data samples for RAGA metrics, ensuring all necessary fields are present
        data_samples = {
            'question': filtered_data['question'].tolist(),
            'answer': filtered_data['Response'].tolist(),
            'contexts': [nltk.sent_tokenize(x) for x in filtered_data['ground_truth']],
            'ground_truth': filtered_data['ground_truth'].tolist()  # Ensuring ground_truth is included for RAGA metrics
        }
        dataset = Dataset.from_dict(data_samples)

        # # Compute RAGA metrics
        # raga_results = evaluate(dataset, metrics=[
        #     faithfulness,
        #     # answer_relevancy, context_precision, context_relevancy,
        #     # context_recall, context_entity_recall,
        #     answer_similarity, answer_correctness
        # ])
        # raga_df = raga_results.to_pandas()

        # # Combine all metrics into a single DataFrame
        # self.metrics_df = pd.concat([filtered_data, raga_df], axis=1)
        # return self.metrics_df

    def get_metrices_from_raga(self, metrices_param):
      # Compute RAGA metrics
      raga_results = evaluate(self.dataset, metrics= metrices_param)
      raga_df = raga_results.to_pandas()
      # Combine all metrics into a single DataFrame
      metrics_df = pd.concat([self.filtered_data, raga_df], axis=1)
      return metrics_df

# %%
metrics_dict = {
    1: 'faithfulness',
    2: 'answer_relevancy',
    3: 'context_precision',
    4: 'context_relevancy',
    5: 'context_recall',
    6: 'context_entity_recall',
    7: 'answer_similarity',
    8: 'answer_correctness'
}

metrics_dict[1]

# %%
# metrics_df.to_csv('/path/to/output/GPT-4_Performance_Metrics.csv', index=False)
evaluator.metrics_df.to_csv('/content/drive/MyDrive/Colab_Notebooks/Capstone_Project/Web_URL/IRS_Models/RAGA/GPT-4_Performance_Metrics.csv', index=False)
print("Performance metrics have been saved successfully.")
print(metrics_df.head())

# %%
evaluator = LLMPerformanceEvaluator(data)

# %%
evaluator.compute_metrics()

# %%
metrices_param = []
for item in metrics_dict.values():
  metrices_param.append(item)
  evaluator.get_metrices_from_raga(metrices_param)

# %%
evaluator.metrics_df.to_csv('/content/drive/MyDrive/Colab_Notebooks/Capstone_Project/Web_URL/IRS_Models/RAGA/GPT-4_Performance_Metrics.csv', index=False)
print("Performance metrics have been saved successfully.")
# print(evaluator.metrics_df.head())
